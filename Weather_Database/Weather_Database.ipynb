# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d22c3a7bc5aacca8fd96c1c53bc614c0

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-augustin
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | cap-aux-meules
# Processing Record 4 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | invermere
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | leh
# Processing Record 9 of Set 1 | crotone
# Processing Record 10 of Set 1 | urucara
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | verkh-usugli
# Processing Record 19 of Set 1 | saint anthony
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | dingle
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | chunhuhub
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | cayenne
# Processing Record 26 of Set 1 | guerrero negro
# Processing Record 27 of Set 1 | chumikan
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | medvezhyegorsk
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | hambantota
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | campbell river
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | pangnirtung
# Processing Record 39 of Set 1 | manadhoo
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | saint-joseph
# Processing Record 43 of Set 1 | oistins
# Processing Record 44 of Set 1 | kazachinskoye
# Processing Record 45 of Set 1 | tuy hoa
# Processing Record 46 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 1 | olafsvik
# Processing Record 48 of Set 1 | sawtell
# Processing Record 49 of Set 1 | japura
# Processing Record 50 of Set 1 | moron
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | faya
# Processing Record 4 of Set 2 | linkou
# Processing Record 5 of Set 2 | oranjestad
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | yar-sale
# Processing Record 9 of Set 2 | luena
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | iracoubo
# Processing Record 12 of Set 2 | bhatkal
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | vada
# Processing Record 16 of Set 2 | teya
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | road town
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 2 | asau
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | qaqortoq
# Processing Record 24 of Set 2 | lorengau
# Processing Record 25 of Set 2 | namatanai
# Processing Record 26 of Set 2 | jaque
# Processing Record 27 of Set 2 | ahipara
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | saldanha
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | nantucket
# Processing Record 32 of Set 2 | college
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | botro
# Processing Record 38 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | iacu
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | saint-martin-boulogne
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | bubaque
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | big bend
# Processing Record 49 of Set 2 | coihaique
# Processing Record 50 of Set 2 | kikwit
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | alofi
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | wukari
# Processing Record 5 of Set 3 | kushnarenkovo
# Processing Record 6 of Set 3 | minatitlan
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | altay
# Processing Record 10 of Set 3 | khani
# Processing Record 11 of Set 3 | touros
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | mirnyy
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | bentiu
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | vestmannaeyjar
# Processing Record 19 of Set 3 | mitchell
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | kaili
# Processing Record 23 of Set 3 | makhinjauri
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | yei
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | sibolga
# Processing Record 29 of Set 3 | tutoia
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | batagay-alyta
# Processing Record 32 of Set 3 | floresta
# Processing Record 33 of Set 3 | san patricio
# Processing Record 34 of Set 3 | caravelas
# Processing Record 35 of Set 3 | manokwari
# Processing Record 36 of Set 3 | kvarkeno
# Processing Record 37 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | dunedin
# Processing Record 41 of Set 3 | miles city
# Processing Record 42 of Set 3 | montmagny
# Processing Record 43 of Set 3 | fare
# Processing Record 44 of Set 3 | rexburg
# Processing Record 45 of Set 3 | banda aceh
# Processing Record 46 of Set 3 | xingcheng
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | chara
# Processing Record 50 of Set 3 | merauke
# Processing Record 1 of Set 4 | mackenzie
# Processing Record 2 of Set 4 | calvinia
# Processing Record 3 of Set 4 | pangai
# Processing Record 4 of Set 4 | shiraz
# Processing Record 5 of Set 4 | belmonte
# Processing Record 6 of Set 4 | sechura
# Processing Record 7 of Set 4 | port blair
# Processing Record 8 of Set 4 | boende
# Processing Record 9 of Set 4 | arlit
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | boa vista
# Processing Record 15 of Set 4 | klaksvik
# Processing Record 16 of Set 4 | olinda
# Processing Record 17 of Set 4 | newport
# Processing Record 18 of Set 4 | sioux lookout
# Processing Record 19 of Set 4 | ararat
# Processing Record 20 of Set 4 | atar
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | kavieng
# Processing Record 23 of Set 4 | qaanaaq
# Processing Record 24 of Set 4 | pisco
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | bereda
# Processing Record 27 of Set 4 | cabatuan
# Processing Record 28 of Set 4 | hawick
# Processing Record 29 of Set 4 | atasu
# Processing Record 30 of Set 4 | tandil
# Processing Record 31 of Set 4 | hovd
# Processing Record 32 of Set 4 | dillon
# Processing Record 33 of Set 4 | baykit
# Processing Record 34 of Set 4 | afgoye
# City not found. Skipping...
# Processing Record 35 of Set 4 | palmer
# Processing Record 36 of Set 4 | alice springs
# Processing Record 37 of Set 4 | coffs harbour
# Processing Record 38 of Set 4 | fonte boa
# Processing Record 39 of Set 4 | canavieiras
# Processing Record 40 of Set 4 | buala
# Processing Record 41 of Set 4 | poum
# Processing Record 42 of Set 4 | kharan
# Processing Record 43 of Set 4 | kaniama
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | ambanja
# Processing Record 48 of Set 4 | ferme-neuve
# Processing Record 49 of Set 4 | sterling
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | fethiye
# Processing Record 2 of Set 5 | topeka
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | chickasha
# Processing Record 5 of Set 5 | lazaro cardenas
# Processing Record 6 of Set 5 | creel
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | port augusta
# Processing Record 9 of Set 5 | asfi
# Processing Record 10 of Set 5 | saint-pierre
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | roald
# Processing Record 13 of Set 5 | shakawe
# Processing Record 14 of Set 5 | manta
# Processing Record 15 of Set 5 | hvolsvollur
# Processing Record 16 of Set 5 | antofagasta
# Processing Record 17 of Set 5 | norman wells
# Processing Record 18 of Set 5 | vuktyl
# Processing Record 19 of Set 5 | paamiut
# Processing Record 20 of Set 5 | alpena
# Processing Record 21 of Set 5 | lasa
# Processing Record 22 of Set 5 | muros
# Processing Record 23 of Set 5 | jizan
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | biak
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | brockville
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | kahului
# Processing Record 30 of Set 5 | camacari
# Processing Record 31 of Set 5 | matay
# Processing Record 32 of Set 5 | sapa
# Processing Record 33 of Set 5 | yendi
# Processing Record 34 of Set 5 | askiz
# Processing Record 35 of Set 5 | nelson bay
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | andra
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | kodinsk
# Processing Record 40 of Set 5 | kutum
# Processing Record 41 of Set 5 | verkhnevilyuysk
# Processing Record 42 of Set 5 | lanzhou
# Processing Record 43 of Set 5 | balkhash
# Processing Record 44 of Set 5 | koromilea
# City not found. Skipping...
# Processing Record 45 of Set 5 | narsaq
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | oussouye
# Processing Record 48 of Set 5 | najran
# Processing Record 49 of Set 5 | waipawa
# Processing Record 50 of Set 5 | sao felix do xingu
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | sol-iletsk
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | vama
# Processing Record 5 of Set 6 | ilulissat
# Processing Record 6 of Set 6 | lompoc
# Processing Record 7 of Set 6 | san cristobal
# Processing Record 8 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 6 | shaunavon
# Processing Record 10 of Set 6 | borogontsy
# Processing Record 11 of Set 6 | weiser
# Processing Record 12 of Set 6 | te anau
# Processing Record 13 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 14 of Set 6 | saint-philippe
# Processing Record 15 of Set 6 | weligama
# Processing Record 16 of Set 6 | richards bay
# Processing Record 17 of Set 6 | ismailia
# Processing Record 18 of Set 6 | dwarka
# Processing Record 19 of Set 6 | kota belud
# Processing Record 20 of Set 6 | priargunsk
# Processing Record 21 of Set 6 | linkoping
# Processing Record 22 of Set 6 | novikovo
# Processing Record 23 of Set 6 | presidente dutra
# Processing Record 24 of Set 6 | muisne
# Processing Record 25 of Set 6 | cherskiy
# Processing Record 26 of Set 6 | tabuk
# Processing Record 27 of Set 6 | okhotsk
# Processing Record 28 of Set 6 | xichang
# Processing Record 29 of Set 6 | polson
# Processing Record 30 of Set 6 | orlik
# Processing Record 31 of Set 6 | airai
# Processing Record 32 of Set 6 | quelimane
# Processing Record 33 of Set 6 | alvarado
# Processing Record 34 of Set 6 | hiriyur
# Processing Record 35 of Set 6 | maceio
# Processing Record 36 of Set 6 | severo-kurilsk
# Processing Record 37 of Set 6 | sept-iles
# Processing Record 38 of Set 6 | natal
# Processing Record 39 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 6 | nabire
# Processing Record 41 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 6 | valerik
# Processing Record 43 of Set 6 | puerto maldonado
# Processing Record 44 of Set 6 | labrea
# Processing Record 45 of Set 6 | gornopravdinsk
# Processing Record 46 of Set 6 | ialibu
# Processing Record 47 of Set 6 | seydi
# Processing Record 48 of Set 6 | ye
# City not found. Skipping...
# Processing Record 49 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | emerald
# Processing Record 2 of Set 7 | itaituba
# Processing Record 3 of Set 7 | saskylakh
# Processing Record 4 of Set 7 | broome
# Processing Record 5 of Set 7 | vila
# Processing Record 6 of Set 7 | sainte-maxime
# Processing Record 7 of Set 7 | egvekinot
# Processing Record 8 of Set 7 | las vegas
# Processing Record 9 of Set 7 | lata
# Processing Record 10 of Set 7 | buraydah
# Processing Record 11 of Set 7 | marawi
# Processing Record 12 of Set 7 | yulara
# Processing Record 13 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | waitati
# Processing Record 16 of Set 7 | emporia
# Processing Record 17 of Set 7 | adre
# Processing Record 18 of Set 7 | coquimbo
# Processing Record 19 of Set 7 | brainerd
# Processing Record 20 of Set 7 | chuy
# Processing Record 21 of Set 7 | batemans bay
# Processing Record 22 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 7 | sale
# Processing Record 24 of Set 7 | thunder bay
# Processing Record 25 of Set 7 | priiskovyy
# Processing Record 26 of Set 7 | fresno
# Processing Record 27 of Set 7 | locri
# Processing Record 28 of Set 7 | fukumitsu
# Processing Record 29 of Set 7 | alyangula
# Processing Record 30 of Set 7 | orcopampa
# Processing Record 31 of Set 7 | codrington
# Processing Record 32 of Set 7 | aripuana
# Processing Record 33 of Set 7 | north myrtle beach
# Processing Record 34 of Set 7 | tubuala
# Processing Record 35 of Set 7 | charters towers
# Processing Record 36 of Set 7 | ziro
# Processing Record 37 of Set 7 | mahibadhoo
# Processing Record 38 of Set 7 | khandyga
# Processing Record 39 of Set 7 | liwale
# Processing Record 40 of Set 7 | zabaykalsk
# Processing Record 41 of Set 7 | mikhaylovka
# Processing Record 42 of Set 7 | victoria
# Processing Record 43 of Set 7 | pakxan
# Processing Record 44 of Set 7 | novaya igirma
# Processing Record 45 of Set 7 | sabla
# Processing Record 46 of Set 7 | kaduqli
# Processing Record 47 of Set 7 | mbarara
# Processing Record 48 of Set 7 | lourdes
# Processing Record 49 of Set 7 | constitucion
# Processing Record 50 of Set 7 | northam
# Processing Record 1 of Set 8 | westport
# Processing Record 2 of Set 8 | singleton
# Processing Record 3 of Set 8 | rundu
# Processing Record 4 of Set 8 | kismayo
# Processing Record 5 of Set 8 | umm lajj
# Processing Record 6 of Set 8 | metsovon
# City not found. Skipping...
# Processing Record 7 of Set 8 | tall kayf
# Processing Record 8 of Set 8 | moindou
# Processing Record 9 of Set 8 | araouane
# Processing Record 10 of Set 8 | pevek
# Processing Record 11 of Set 8 | yarovoye
# Processing Record 12 of Set 8 | belaya gora
# Processing Record 13 of Set 8 | laguna
# Processing Record 14 of Set 8 | kambarka
# Processing Record 15 of Set 8 | katherine
# Processing Record 16 of Set 8 | agva
# City not found. Skipping...
# Processing Record 17 of Set 8 | colares
# Processing Record 18 of Set 8 | shellbrook
# Processing Record 19 of Set 8 | vardo
# Processing Record 20 of Set 8 | kargasok
# Processing Record 21 of Set 8 | linxia
# Processing Record 22 of Set 8 | khorol
# Processing Record 23 of Set 8 | fecamp
# Processing Record 24 of Set 8 | santa cruz de la palma
# Processing Record 25 of Set 8 | ningan
# City not found. Skipping...
# Processing Record 26 of Set 8 | san ramon
# Processing Record 27 of Set 8 | gat
# Processing Record 28 of Set 8 | ilhabela
# Processing Record 29 of Set 8 | dum duma
# Processing Record 30 of Set 8 | nuuk
# Processing Record 31 of Set 8 | russkaya polyana
# Processing Record 32 of Set 8 | padang
# Processing Record 33 of Set 8 | faanui
# Processing Record 34 of Set 8 | sao filipe
# Processing Record 35 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 8 | cap malheureux
# Processing Record 37 of Set 8 | del rio
# Processing Record 38 of Set 8 | bowen
# Processing Record 39 of Set 8 | putina
# Processing Record 40 of Set 8 | jasper
# Processing Record 41 of Set 8 | coruripe
# Processing Record 42 of Set 8 | kieta
# Processing Record 43 of Set 8 | bayonet point
# Processing Record 44 of Set 8 | mpanda
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | vorkuta
# Processing Record 47 of Set 8 | cabinda
# Processing Record 48 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | skibbereen
# Processing Record 50 of Set 8 | black river
# Processing Record 1 of Set 9 | lebu
# Processing Record 2 of Set 9 | vagur
# Processing Record 3 of Set 9 | beringovskiy
# Processing Record 4 of Set 9 | aasiaat
# Processing Record 5 of Set 9 | ballina
# Processing Record 6 of Set 9 | harqalah
# Processing Record 7 of Set 9 | zeya
# Processing Record 8 of Set 9 | carbonia
# Processing Record 9 of Set 9 | conakry
# Processing Record 10 of Set 9 | odweyne
# Processing Record 11 of Set 9 | rocha
# Processing Record 12 of Set 9 | johnstown
# Processing Record 13 of Set 9 | byron bay
# Processing Record 14 of Set 9 | sorong
# Processing Record 15 of Set 9 | macamic
# Processing Record 16 of Set 9 | soavinandriana
# Processing Record 17 of Set 9 | saint-francois
# Processing Record 18 of Set 9 | bud
# Processing Record 19 of Set 9 | san carlos de bariloche
# Processing Record 20 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 9 | dwarahat
# Processing Record 22 of Set 9 | rio gallegos
# Processing Record 23 of Set 9 | samarai
# Processing Record 24 of Set 9 | hertford
# Processing Record 25 of Set 9 | omsukchan
# Processing Record 26 of Set 9 | koumac
# Processing Record 27 of Set 9 | flinders
# Processing Record 28 of Set 9 | fairbanks
# Processing Record 29 of Set 9 | hamilton
# Processing Record 30 of Set 9 | hongjiang
# Processing Record 31 of Set 9 | xiamen
# Processing Record 32 of Set 9 | cururupu
# Processing Record 33 of Set 9 | bandar-e lengeh
# Processing Record 34 of Set 9 | pudozh
# Processing Record 35 of Set 9 | impfondo
# Processing Record 36 of Set 9 | lensk
# Processing Record 37 of Set 9 | tevaitoa
# Processing Record 38 of Set 9 | taman
# Processing Record 39 of Set 9 | iberia
# Processing Record 40 of Set 9 | vanimo
# Processing Record 41 of Set 9 | morondava
# Processing Record 42 of Set 9 | xiongshi
# City not found. Skipping...
# Processing Record 43 of Set 9 | berdigestyakh
# Processing Record 44 of Set 9 | berlevag
# Processing Record 45 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 9 | rawson
# Processing Record 47 of Set 9 | isangel
# Processing Record 48 of Set 9 | umm kaddadah
# Processing Record 49 of Set 9 | novaya lyada
# Processing Record 50 of Set 9 | novoagansk
# Processing Record 1 of Set 10 | dali
# Processing Record 2 of Set 10 | tessalit
# Processing Record 3 of Set 10 | barcelona
# Processing Record 4 of Set 10 | the valley
# Processing Record 5 of Set 10 | dalbandin
# Processing Record 6 of Set 10 | smoky lake
# Processing Record 7 of Set 10 | buluang
# Processing Record 8 of Set 10 | ulladulla
# Processing Record 9 of Set 10 | vicksburg
# Processing Record 10 of Set 10 | labuhan
# Processing Record 11 of Set 10 | malinyi
# Processing Record 12 of Set 10 | takoradi
# Processing Record 13 of Set 10 | mecca
# Processing Record 14 of Set 10 | sur
# Processing Record 15 of Set 10 | taksimo
# Processing Record 16 of Set 10 | sao joao dos patos
# Processing Record 17 of Set 10 | kozhva
# Processing Record 18 of Set 10 | kemise
# Processing Record 19 of Set 10 | areosa
# Processing Record 20 of Set 10 | tanshui
# City not found. Skipping...
# Processing Record 21 of Set 10 | mangan
# Processing Record 22 of Set 10 | inta
# Processing Record 23 of Set 10 | mandurah
# Processing Record 24 of Set 10 | avera
# Processing Record 25 of Set 10 | sistranda
# Processing Record 26 of Set 10 | saint-georges
# Processing Record 27 of Set 10 | muscat
# Processing Record 28 of Set 10 | nakhon ratchasima
# Processing Record 29 of Set 10 | nyurba
# Processing Record 30 of Set 10 | verkhniy mamon
# Processing Record 31 of Set 10 | bollnas
# Processing Record 32 of Set 10 | kudahuvadhoo
# Processing Record 33 of Set 10 | marienburg
# Processing Record 34 of Set 10 | omboue
# Processing Record 35 of Set 10 | aklavik
# Processing Record 36 of Set 10 | harbour breton
# Processing Record 37 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 10 | urumqi
# Processing Record 39 of Set 10 | sabha
# Processing Record 40 of Set 10 | dryden
# Processing Record 41 of Set 10 | lingao
# Processing Record 42 of Set 10 | darya khan mari
# City not found. Skipping...
# Processing Record 43 of Set 10 | astoria
# Processing Record 44 of Set 10 | cariati
# Processing Record 45 of Set 10 | mayumba
# Processing Record 46 of Set 10 | teguise
# Processing Record 47 of Set 10 | san quintin
# Processing Record 48 of Set 10 | mount vernon
# Processing Record 49 of Set 10 | flin flon
# Processing Record 50 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | bathsheba
# Processing Record 3 of Set 11 | kirra
# Processing Record 4 of Set 11 | poso
# Processing Record 5 of Set 11 | yuzhne
# Processing Record 6 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 11 | mafeteng
# Processing Record 8 of Set 11 | sobolevo
# Processing Record 9 of Set 11 | yarmouth
# Processing Record 10 of Set 11 | svetlogorsk
# Processing Record 11 of Set 11 | saravan
# Processing Record 12 of Set 11 | bandarbeyla
# Processing Record 13 of Set 11 | rio grande
# Processing Record 14 of Set 11 | tura
# Processing Record 15 of Set 11 | sao joao da barra
# Processing Record 16 of Set 11 | adrar
# Processing Record 17 of Set 11 | diu
# Processing Record 18 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 11 | vestmanna
# Processing Record 20 of Set 11 | arica
# Processing Record 21 of Set 11 | remanso
# Processing Record 22 of Set 11 | tsurib
# Processing Record 23 of Set 11 | san jeronimo
# Processing Record 24 of Set 11 | jijiga
# Processing Record 25 of Set 11 | kangaatsiaq
# Processing Record 26 of Set 11 | xai-xai
# Processing Record 27 of Set 11 | neuquen
# Processing Record 28 of Set 11 | san pedro
# Processing Record 29 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | xingyi
# Processing Record 31 of Set 11 | bull savanna
# Processing Record 32 of Set 11 | ostrovnoy
# Processing Record 33 of Set 11 | meulaboh
# Processing Record 34 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 35 of Set 11 | barao de melgaco
# Processing Record 36 of Set 11 | talnakh
# Processing Record 37 of Set 11 | half moon bay
# Processing Record 38 of Set 11 | champerico
# Processing Record 39 of Set 11 | port hardy
# Processing Record 40 of Set 11 | whitehorse
# Processing Record 41 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 11 | amahai
# Processing Record 43 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 11 | bartica
# Processing Record 45 of Set 11 | deputatskiy
# Processing Record 46 of Set 11 | imeni poliny osipenko
# Processing Record 47 of Set 11 | north bend
# Processing Record 48 of Set 11 | west wendover
# Processing Record 49 of Set 11 | hamina
# Processing Record 50 of Set 11 | wangaratta
# Processing Record 1 of Set 12 | luderitz
# Processing Record 2 of Set 12 | acarau
# Processing Record 3 of Set 12 | zhezkazgan
# Processing Record 4 of Set 12 | novyy urengoy
# Processing Record 5 of Set 12 | tilichiki
# Processing Record 6 of Set 12 | nara
# Processing Record 7 of Set 12 | trujillo
# Processing Record 8 of Set 12 | la asuncion
# Processing Record 9 of Set 12 | esfarayen
# Processing Record 10 of Set 12 | parangan
# Processing Record 11 of Set 12 | ust-kalmanka
# Processing Record 12 of Set 12 | navahrudak
# Processing Record 13 of Set 12 | caborca
# Processing Record 14 of Set 12 | logstor
# Processing Record 15 of Set 12 | shingu
# Processing Record 16 of Set 12 | manggar
# Processing Record 17 of Set 12 | mareeba
# Processing Record 18 of Set 12 | tsabong
# Processing Record 19 of Set 12 | kavaratti
# Processing Record 20 of Set 12 | otane
# Processing Record 21 of Set 12 | mersing
# Processing Record 22 of Set 12 | ouango
# Processing Record 23 of Set 12 | tulsipur
# Processing Record 24 of Set 12 | pesqueria
# Processing Record 25 of Set 12 | lagoa
# Processing Record 26 of Set 12 | swift current
# Processing Record 27 of Set 12 | lukovetskiy
# Processing Record 28 of Set 12 | russell
# Processing Record 29 of Set 12 | ambilobe
# Processing Record 30 of Set 12 | buin
# Processing Record 31 of Set 12 | cadereyta
# Processing Record 32 of Set 12 | banjar
# Processing Record 33 of Set 12 | liverpool
# Processing Record 34 of Set 12 | baie-saint-paul
# Processing Record 35 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 36 of Set 12 | san sebastian de los reyes
# Processing Record 37 of Set 12 | port-gentil
# Processing Record 38 of Set 12 | aguilas
# Processing Record 39 of Set 12 | durango
# Processing Record 40 of Set 12 | koindu
# Processing Record 41 of Set 12 | kayseri
# Processing Record 42 of Set 12 | beyneu
# Processing Record 43 of Set 12 | inhambane
# Processing Record 44 of Set 12 | panama city
# Processing Record 45 of Set 12 | tucuman
# Processing Record 46 of Set 12 | naryan-mar
# Processing Record 47 of Set 12 | puerto baquerizo moreno
# Processing Record 48 of Set 12 | yining
# Processing Record 49 of Set 12 | kingseat
# Processing Record 50 of Set 12 | bambanglipuro
# Processing Record 1 of Set 13 | talcahuano
# Processing Record 2 of Set 13 | gallup
# Processing Record 3 of Set 13 | les cayes
# Processing Record 4 of Set 13 | williamsport
# Processing Record 5 of Set 13 | ust-barguzin
# Processing Record 6 of Set 13 | ewa beach
# Processing Record 7 of Set 13 | yunguyo
# Processing Record 8 of Set 13 | harper
# Processing Record 9 of Set 13 | capilla de guadalupe
# Processing Record 10 of Set 13 | cangucu
# Processing Record 11 of Set 13 | suntar
# Processing Record 12 of Set 13 | olga
# Processing Record 13 of Set 13 | luganville
# Processing Record 14 of Set 13 | barra do garcas
# Processing Record 15 of Set 13 | oudtshoorn
# Processing Record 16 of Set 13 | kasongo-lunda
# Processing Record 17 of Set 13 | kazanskaya
# Processing Record 18 of Set 13 | praia da vitoria
# Processing Record 19 of Set 13 | port hawkesbury
# Processing Record 20 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 13 | hope
# Processing Record 22 of Set 13 | khammam
# Processing Record 23 of Set 13 | kongolo
# Processing Record 24 of Set 13 | finschhafen
# Processing Record 25 of Set 13 | jidong
# Processing Record 26 of Set 13 | melfi
# Processing Record 27 of Set 13 | den helder
# Processing Record 28 of Set 13 | waingapu
# Processing Record 29 of Set 13 | shatrovo
# Processing Record 30 of Set 13 | preobrazheniye
# Processing Record 31 of Set 13 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 13 | torit
# Processing Record 33 of Set 13 | yumen
# Processing Record 34 of Set 13 | mitsamiouli
# Processing Record 35 of Set 13 | cedar city
# Processing Record 36 of Set 13 | itarema
# Processing Record 37 of Set 13 | yelizovo
# Processing Record 38 of Set 13 | la serena
# Processing Record 39 of Set 13 | axim
# Processing Record 40 of Set 13 | kamaishi
# Processing Record 41 of Set 13 | amga
# Processing Record 42 of Set 13 | chiang khong
# Processing Record 43 of Set 13 | minot
# Processing Record 44 of Set 13 | taoudenni
# Processing Record 45 of Set 13 | qingan
# City not found. Skipping...
# Processing Record 46 of Set 13 | manicore
# Processing Record 47 of Set 13 | forbes
# Processing Record 48 of Set 13 | barra da estiva
# Processing Record 49 of Set 13 | pangody
# Processing Record 50 of Set 13 | pierre
# Processing Record 1 of Set 14 | along
# Processing Record 2 of Set 14 | sisimiut
# Processing Record 3 of Set 14 | korla
# Processing Record 4 of Set 14 | warrnambool
# Processing Record 5 of Set 14 | kankan
# Processing Record 6 of Set 14 | mokhsogollokh
# Processing Record 7 of Set 14 | port moresby
# Processing Record 8 of Set 14 | krabi
# Processing Record 9 of Set 14 | great yarmouth
# Processing Record 10 of Set 14 | malanville
# Processing Record 11 of Set 14 | la ronge
# Processing Record 12 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 14 | darnah
# Processing Record 14 of Set 14 | homburg
# Processing Record 15 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 14 | awjilah
# Processing Record 17 of Set 14 | oranjemund
# Processing Record 18 of Set 14 | ocean city
# Processing Record 19 of Set 14 | manjacaze
# Processing Record 20 of Set 14 | wajima
# Processing Record 21 of Set 14 | tacoronte
# Processing Record 22 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 14 | yerbogachen
# Processing Record 24 of Set 14 | mogok
# Processing Record 25 of Set 14 | mabai
# Processing Record 26 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 14 | jiuquan
# Processing Record 28 of Set 14 | vostok
# Processing Record 29 of Set 14 | killybegs
# Processing Record 30 of Set 14 | thessalon
# Processing Record 31 of Set 14 | tokur
# Processing Record 32 of Set 14 | oktyabrskiy
# Processing Record 33 of Set 14 | tari
# Processing Record 34 of Set 14 | nome
# Processing Record 35 of Set 14 | burnie
# Processing Record 36 of Set 14 | magadan
# Processing Record 37 of Set 14 | krasnoselkup
# Processing Record 38 of Set 14 | sakaiminato
# Processing Record 39 of Set 14 | honiara
# Processing Record 40 of Set 14 | bairiki
# Processing Record 41 of Set 14 | mana
# Processing Record 42 of Set 14 | pyshchug
# Processing Record 43 of Set 14 | puebla
# Processing Record 44 of Set 14 | crnomelj
# Processing Record 45 of Set 14 | kropotkin
# Processing Record 46 of Set 14 | cockburn town
# Processing Record 47 of Set 14 | ayorou
# Processing Record 48 of Set 14 | derzhavinsk
# Processing Record 49 of Set 14 | yatou
# Processing Record 50 of Set 14 | salta
# Processing Record 1 of Set 15 | sosnogorsk
# Processing Record 2 of Set 15 | evensk
# Processing Record 3 of Set 15 | sungaipenuh
# Processing Record 4 of Set 15 | eyl
# Processing Record 5 of Set 15 | semporna
# Processing Record 6 of Set 15 | san-pedro
# Processing Record 7 of Set 15 | xining
# Processing Record 8 of Set 15 | bintulu
# Processing Record 9 of Set 15 | zambezi
# Processing Record 10 of Set 15 | kem
# Processing Record 11 of Set 15 | mount isa
# Processing Record 12 of Set 15 | muravlenko
# Processing Record 13 of Set 15 | vitim
# Processing Record 14 of Set 15 | ferkessedougou
# Processing Record 15 of Set 15 | yalvac
# Processing Record 16 of Set 15 | gubkinskiy
# Processing Record 17 of Set 15 | burica
# City not found. Skipping...
# Processing Record 18 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 15 | maniitsoq
# Processing Record 20 of Set 15 | igdir
# Processing Record 21 of Set 15 | canutama
# Processing Record 22 of Set 15 | saurimo
# Processing Record 23 of Set 15 | malpe
# Processing Record 24 of Set 15 | ampanihy
# Processing Record 25 of Set 15 | tornio
# Processing Record 26 of Set 15 | sorland
# Processing Record 27 of Set 15 | mahon
# Processing Record 28 of Set 15 | singkang
# Processing Record 29 of Set 15 | mildura
# Processing Record 30 of Set 15 | watsa
# Processing Record 31 of Set 15 | pemberton
# Processing Record 32 of Set 15 | terrak
# Processing Record 33 of Set 15 | miranda
# Processing Record 34 of Set 15 | kimbe
# Processing Record 35 of Set 15 | muzhi
# Processing Record 36 of Set 15 | santa rosa
# Processing Record 37 of Set 15 | krutinka
# Processing Record 38 of Set 15 | acurenam
# Processing Record 39 of Set 15 | marzuq
# Processing Record 40 of Set 15 | guiratinga
# Processing Record 41 of Set 15 | paoua
# Processing Record 42 of Set 15 | nyzhnya duvanka
# Processing Record 43 of Set 15 | ozieri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Augustin  51.2260  -58.6502     25.81        94         100
# 1      Bredasdorp -34.5322   20.0403     66.20        72           0
# 2  Cap-Aux-Meules  47.3821  -61.8597     19.40        86         100
# 3     Tuktoyaktuk  69.4541 -133.0374     -4.00        84          90
# 4       Invermere  50.5167 -116.0354     35.01        92         100
# 5           Kapaa  22.0752 -159.3190     69.80        83          90
# 6             Leh  34.1667   77.5833     15.03        80          94
# 7         Crotone  39.0851   17.1178     51.80        82          40
# 8         Urucara  -2.5364  -57.7600     83.80        78          99
# 9       Mahebourg -20.4081   57.7000     80.60        78          75
#
#    Wind Speed Country Current Description
# 0       16.51      CA     overcast clouds
# 1       13.80      ZA           clear sky
# 2       17.27      CA     overcast clouds
# 3        5.75      CA          light snow
# 4        1.01      CA     overcast clouds
# 5       20.71      US          light rain
# 6        0.87      IN     overcast clouds
# 7        6.91      IT    scattered clouds
# 8        0.94      BR     overcast clouds
# 9        4.61      MU       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Augustin      CA  51.2260  -58.6502     25.81        94         100
# 1      Bredasdorp      ZA -34.5322   20.0403     66.20        72           0
# 2  Cap-Aux-Meules      CA  47.3821  -61.8597     19.40        86         100
# 3     Tuktoyaktuk      CA  69.4541 -133.0374     -4.00        84          90
# 4       Invermere      CA  50.5167 -116.0354     35.01        92         100
# 5           Kapaa      US  22.0752 -159.3190     69.80        83          90
# 6             Leh      IN  34.1667   77.5833     15.03        80          94
# 7         Crotone      IT  39.0851   17.1178     51.80        82          40
# 8         Urucara      BR  -2.5364  -57.7600     83.80        78          99
# 9       Mahebourg      MU -20.4081   57.7000     80.60        78          75
#
#    Wind Speed Current Description
# 0       16.51     overcast clouds
# 1       13.80           clear sky
# 2       17.27     overcast clouds
# 3        5.75          light snow
# 4        1.01     overcast clouds
# 5       20.71          light rain
# 6        0.87     overcast clouds
# 7        6.91    scattered clouds
# 8        0.94     overcast clouds
# 9        4.61       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
