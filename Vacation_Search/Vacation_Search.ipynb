# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Saint-Augustin      CA  51.2260  -58.6502     25.81        94
# 1        1      Bredasdorp      ZA -34.5322   20.0403     66.20        72
# 2        2  Cap-Aux-Meules      CA  47.3821  -61.8597     19.40        86
# 3        3     Tuktoyaktuk      CA  69.4541 -133.0374     -4.00        84
# 4        4       Invermere      CA  50.5167 -116.0354     35.01        92
#
#    Cloudiness  Wind Speed Current Description
# 0         100       16.51     overcast clouds
# 1           0       13.80           clear sky
# 2         100       17.27     overcast clouds
# 3          90        5.75          light snow
# 4         100        1.01     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 8         8       Urucara      BR  -2.5364  -57.7600     83.80        78
# 9         9     Mahebourg      MU -20.4081   57.7000     80.60        78
# 11       11         Vaini      TO -21.2000 -175.2000     78.80        94
# 12       12      Cidreira      BR -30.1811  -50.2056     76.15        58
# 17       17       Rikitea      PF -23.1203 -134.9692     79.93        82
# 20       20     Chunhuhub      MX  19.5500  -88.6833     89.94        42
# 22       22       Cayenne      GF   4.9333  -52.3333     75.20        94
# 32       32    Butaritari      KI   3.0707  172.7902     79.84        81
# 35       35      Manadhoo      MV   5.7667   73.3833     83.01        64
# 38       38  Saint-Joseph      RE -21.3667   55.6167     78.80        78
#
#     Cloudiness  Wind Speed Current Description
# 8           99        0.94     overcast clouds
# 9           75        4.61       broken clouds
# 11          75        9.22       broken clouds
# 12           7       11.56           clear sky
# 17          16       12.08          few clouds
# 20          61        3.69       broken clouds
# 22          75        8.05       moderate rain
# 32          38       14.58    scattered clouds
# 35           0        6.85           clear sky
# 38          90        4.61     overcast clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                200
# City                   200
# Country                200
# Lat                    200
# Lng                    200
# Max Temp               200
# Humidity               200
# Cloudiness             200
# Wind Speed             200
# Current Description    200
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 8        Urucara      BR     83.80     overcast clouds  -2.5364  -57.7600
# 9      Mahebourg      MU     80.60       broken clouds -20.4081   57.7000
# 11         Vaini      TO     78.80       broken clouds -21.2000 -175.2000
# 12      Cidreira      BR     76.15           clear sky -30.1811  -50.2056
# 17       Rikitea      PF     79.93          few clouds -23.1203 -134.9692
# 20     Chunhuhub      MX     89.94       broken clouds  19.5500  -88.6833
# 22       Cayenne      GF     75.20       moderate rain   4.9333  -52.3333
# 32    Butaritari      KI     79.84    scattered clouds   3.0707  172.7902
# 35      Manadhoo      MV     83.01           clear sky   5.7667   73.3833
# 38  Saint-Joseph      RE     78.80     overcast clouds -21.3667   55.6167
#
#    Hotel Name
# 8
# 9
# 11
# 12
# 17
# 20
# 22
# 32
# 35
# 38

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
        
hotel_df.head(10)
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
#             City Country  Max Temp Current Description      Lat       Lng  \
# 8        Urucara      BR     83.80     overcast clouds  -2.5364  -57.7600
# 9      Mahebourg      MU     80.60       broken clouds -20.4081   57.7000
# 11         Vaini      TO     78.80       broken clouds -21.2000 -175.2000
# 12      Cidreira      BR     76.15           clear sky -30.1811  -50.2056
# 17       Rikitea      PF     79.93          few clouds -23.1203 -134.9692
# 20     Chunhuhub      MX     89.94       broken clouds  19.5500  -88.6833
# 22       Cayenne      GF     75.20       moderate rain   4.9333  -52.3333
# 32    Butaritari      KI     79.84    scattered clouds   3.0707  172.7902
# 35      Manadhoo      MV     83.01           clear sky   5.7667   73.3833
# 38  Saint-Joseph      RE     78.80     overcast clouds -21.3667   55.6167
#
#                             Hotel Name
# 8                           Hotel japa
# 9   Shandrani Beachcomber Resort & Spa
# 11                 Keleti Beach Resort
# 12                       Hotel Castelo
# 17                      Pension Maro'i
# 20
# 22                     Hôtel Le Dronmi
# 32                  Isles Sunset Lodge
# 35                     Vevu Guesthouse
# 38       "Plantation Bed and Breakfast

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.loc[hotel_df["Hotel Name"] == ""]["Hotel Name"] = None
clean_hotel_df = hotel_df.dropna()
clean_hotel_df.head(20)
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 8        Urucara      BR     83.80     overcast clouds  -2.5364  -57.7600
# 9      Mahebourg      MU     80.60       broken clouds -20.4081   57.7000
# 11         Vaini      TO     78.80       broken clouds -21.2000 -175.2000
# 12      Cidreira      BR     76.15           clear sky -30.1811  -50.2056
# 17       Rikitea      PF     79.93          few clouds -23.1203 -134.9692
# 22       Cayenne      GF     75.20       moderate rain   4.9333  -52.3333
# 32    Butaritari      KI     79.84    scattered clouds   3.0707  172.7902
# 35      Manadhoo      MV     83.01           clear sky   5.7667   73.3833
# 38  Saint-Joseph      RE     78.80     overcast clouds -21.3667   55.6167
# 39       Oistins      BB     84.20    scattered clouds  13.0667  -59.5333
# 45         Moron      AR     82.99           clear sky -34.6534  -58.6198
# 49    Oranjestad      AW     84.20          few clouds  12.5240  -70.0270
# 51        Castro      BR     75.42          few clouds -24.7911  -50.0119
# 55      Iracoubo      GF     79.66     overcast clouds   5.4802  -53.2011
# 56       Bhatkal      IN     78.01           clear sky  13.9667   74.5667
# 62     Road Town      VG     84.20          few clouds  18.4167  -64.6167
# 65        Atuona      PF     80.40           clear sky  -9.8000 -139.0333
# 67      Lorengau      PG     80.89          light rain  -2.0226  147.2712
# 68     Namatanai      PG     78.87       broken clouds  -3.6667  152.4333
# 69         Jaque      PA     84.92    scattered clouds   7.5175  -78.1703
#
#                                         Hotel Name
# 8                                       Hotel japa
# 9               Shandrani Beachcomber Resort & Spa
# 11                             Keleti Beach Resort
# 12                                   Hotel Castelo
# 17                                  Pension Maro'i
# 22                                 Hôtel Le Dronmi
# 32                              Isles Sunset Lodge
# 35                                 Vevu Guesthouse
# 38                   "Plantation Bed and Breakfast
# 39                           Butterfly Beach Hotel
# 45                                     Hotel Morón
# 49                Divi Village Golf & Beach Resort
# 51                                  CHACARA BAILLY
# 55                              Le Gite D Iracoubo
# 56              SPOT ON 61793 Chaya Residency SPOT
# 62  ZINGARA 76ft Catamaran, full crew-all included
# 65                                     Villa Enata
# 67                      Lorengau Harbourside Hotel
# 68                                 Namatanai Hotel
# 69                                  Imbu Bua Lodge

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F<dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = locations
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
